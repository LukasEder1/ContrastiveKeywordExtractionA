# %%
import yake
import sqlite3
import pandas as pd
from news_processing import *
from keyword_extraction import *
from summa import summarizer
import difflib
import nltk
from sentence_transformers import SentenceTransformer, util
import numpy as np
from LexRank import degree_centrality_scores
import re
from yake.highlight import *

# %%
conn = sqlite3.connect('../datasets/ap-matched-sentences.db')
connection = sqlite3.connect('../datasets/ap.db')
pd.options.display.max_colwidth = 500

# %%
article_id = 2
data = create_data(article_id, conn)
versions = get_versions(data)
print(f"Available versions: {versions}\n")
documents = get_documents(data)
# Out:
# Available versions: {0.0, 1.0, 2.0, 3.0}

# %%
def find_important_indices(important_sentences, document):
    
    # split into sentences
    sentences = nltk.sent_tokenize(document)
    
    # list of indices corresponding to the important sentences 
    important_indices = []
    
    for important_sentence in important_sentences:
        for idx in range(len(sentences)):
            if important_sentence == sentences[idx]:
                important_indices.append(idx)
                
    return important_indices

# %% [markdown]
# ## TextRank Importance Ranking

# %%
def text_rank(documents):
    number_of_documents = len(documents)
    important_sentences = {version:[] for version in range(number_of_documents)}
    important_indices = {version:[] for version in range(number_of_documents)}
    for current in range(number_of_documents):
        
        # current document
        document = documents[current]
        
        # find most important sentences
        summary = summarizer.summarize(document).strip()
        
        # tokenize into seprate sentences
        important_sentences[current] = nltk.sent_tokenize(summary)
            
        # find corresponding indices in original corpus
        important_indices[current] = find_important_indices(important_sentences[current], document)
        
    return important_sentences, important_indices

# %%
sentences, indices = text_rank(documents)
indices
# Out:
# {0: [4, 5, 6, 17, 18, 19, 20, 21, 24],
#  1: [4, 5, 6, 8, 9, 10, 11, 18, 19, 20, 21, 22, 23, 26],
#  2: [4, 5, 6, 8, 9, 10, 11, 19, 20, 21, 22, 23, 24, 27],
#  3: [1, 6, 10, 15, 20, 29, 34, 39, 47, 51, 62, 63]}

# %% [markdown]
# ## LexRank importance Ranking

# %%
"""
This example uses LexRank (https://www.aaai.org/Papers/JAIR/Vol22/JAIR-2214.pdf)
to create an extractive summarization of a long document.
The document is splitted into sentences using NLTK, then the sentence embeddings are computed. We
then compute the cosine-similarity across all possible sentence pairs.
We then use LexRank to find the most central sentences in the document, which form our summary.
"""

def lex_rank(documents, n=10, model='all-MiniLM-L6-v2'):
    model = SentenceTransformer(model)

    # Our input document we want to summarize
    # As example, we take the first section from Wikipedia
    
    number_of_documents = len(documents)
    important_sentences = {version:[] for version in range(number_of_documents)}
    important_indices = {version:[] for version in range(number_of_documents)}
    
    for current in range(number_of_documents):
    #Split the document into sentences
        sentences = nltk.sent_tokenize(documents[current])

        #Compute the sentence embeddings
        embeddings = model.encode(sentences, convert_to_tensor=True)

        #Compute the pair-wise cosine similarities
        cos_scores = util.cos_sim(embeddings, embeddings).numpy()

        #Compute the centrality for each sentence
        centrality_scores = degree_centrality_scores(cos_scores, threshold=None)

        #We argsort so that the first element is the sentence with the highest score
        most_central_sentence_indices = np.argsort(-centrality_scores)


        #use the n sentences with the highest scores
        top_sentences = []
        top_indices = []
        for idx in most_central_sentence_indices[0:n]:
            top_sentences.append(sentences[idx].strip())
            top_indices.append(idx)
            
        important_sentences[current] = top_sentences
        important_indices[current] = top_indices
        
    return important_sentences, important_indices

# %%
sentences, indices = lex_rank(documents, 5)

# %%
print(indices)
# Out:
# {0: [0, 7, 20, 11, 3], 1: [0, 22, 13, 24, 3], 2: [0, 13, 23, 28, 25], 3: [59, 1, 32, 61, 39]}

# %% [markdown]
# ## Yake! Keyword Highlighting and Ranking

# %%
def yake_keyword_frequency(documents, ngram_size=3):
    
    number_of_documents = len(documents)
    
    # dictonary of form: version -> keywords
    keywords = extract_yake(documents) 
    
    # init highlighter object
    highlighter = TextHighlighter(max_ngram_size = ngram_size)
    
    # save the sentence specific keyword counts for all documents
    keyword_counts = []
    
    for current in range(number_of_documents):
        
        # current number of sentences
        number_of_sentences = len(nltk.sent_tokenize(documents[current]))
        
        # dictonary to count number of keywords in a sentence
        keyword_count = {sentence:0 for sentence in range(number_of_sentences)}
        
        # highlight keywords in text
        highlightet_text = highlighter.highlight(documents[current], keywords[current])
        
        # split document into sentences
        highlightet_sentences = nltk.sent_tokenize(highlightet_text)
        
        # used to determine the current position in the corpus
        sentence_position = 0
        
        for sentence in highlightet_sentences:
            
            # find all keywords in current sentence
            current_keywords = re.findall(r"<kw>(.*?)</kw>", sentence)
            
            keyword_count[sentence_position] = len(current_keywords)
            
            sentence_position += 1
        
        keyword_counts.append(keyword_count)
        
    return keyword_counts

# %%
def yake_weighted_keyword_frequency(documents, ngram_size=3):
    
    number_of_documents = len(documents)
    
    # dictonary of form: version -> keywords
    keywords = extract_yake(documents)
    
    # init highlighter object
    highlighter = TextHighlighter(max_ngram_size = ngram_size)
    
    # save the sentence specific keyword counts for all documents
    keyword_counts = []
    
    for current in range(number_of_documents):
        
        # current number of sentences
        number_of_sentences = len(nltk.sent_tokenize(documents[current]))
        
        # dictonary to count number of keywords in a sentence
        keyword_count = {sentence:0 for sentence in range(number_of_sentences)}
        
        # highlight keywords in text
        highlightet_text = highlighter.highlight(documents[current], keywords[current])
        
        # split document into sentences
        highlightet_sentences = nltk.sent_tokenize(highlightet_text)
        
        # used to determine the current position in the corpus
        sentence_position = 0
        
        for sentence in highlightet_sentences:
            
            # find all keywords in current sentence
            current_keywords = re.findall(r"<kw>(.*?)</kw>", sentence)
            
            # combine the score of the keywords
            # take the inverse since YAKE! goes from lowest -> highest
            combined_keyword_scores = sum([1/score for keyword, score in keywords[current] 
                                           if keyword in current_keywords])
            
            # weighted count
            keyword_count[sentence_position] = len(current_keywords) * combined_keyword_scores
            
            sentence_position += 1
        
        keyword_counts.append(keyword_count)
        
    return keyword_counts

# %%
def rank_yake(documents, keyword_counts, top_n=5):
    number_of_documents = len(documents)
    
    important_sentences = {version:[] for version in range(number_of_documents)}
    important_indices = {version:[] for version in range(number_of_documents)}
    ranking = {version:{} for version in range(number_of_documents)}
    
    eps = 0.01
    # document index
    current = 0
    
    
    for counts in keyword_counts:
        
        
        sentences  = nltk.sent_tokenize(documents[current])
        
        # get the length of each sentence
        sentence_lengths = [len(sentence) for sentence in sentences]
        
        # normalize keyword counts by sentence length
        # In order to not give longer sentences more importance
        normalized_counts = {k: (v/sentence_lengths[i]) + eps for i, (k, v) in enumerate(counts.items())}
    
        # sort counts by number of keyword frequency (highest -> lowest)
        sorted_counts = {k: v for k, v in sorted(normalized_counts.items(), key=lambda item: item[1], 
                                                 reverse=True)}
        
        # sorted sentence idices, by highest keyword frequencies
        top_keys = list(sorted_counts.keys())
        
        # return the top_n most important sentences
        important_sentences[current] = [sentences[idx] for idx in top_keys[:top_n]]
        
        # return the top_n most important indices
        important_indices[current] = top_keys[:top_n]
        
        ranking[current] = sorted_counts
        
        current += 1
    
    return important_sentences, important_indices, ranking

# %%
keyword_weighted_counts = yake_weighted_keyword_frequency(documents, ngram_size=3)
sentencesw, indicesw, rankingw = rank_yake(documents, keyword_weighted_counts)
rankingw
# Out:
# {0: {0: 6.02022619263948,
#   1: 5.712770200464182,
#   11: 4.343472071951212,
#   6: 3.4422221341927437,
#   24: 3.200820555933037,
#   16: 2.816171006197526,
#   8: 2.0408555102275625,
#   3: 1.6733713377295332,
#   2: 1.6706501034595735,
#   20: 1.5210146827600213,
#   22: 1.3945596093333295,
#   14: 1.1772215448464776,
#   15: 0.9974404063783755,
#   26: 0.9699398996430829,
#   27: 0.9483120366679418,
#   4: 0.678659578454766,
#   10: 0.4988691549753754,
#   13: 0.41379083931679345,
#   9: 0.1578269639822564,
#   7: 0.14161905955894438,
#   28: 0.09045076413888356,
#   5: 0.08857981613565372,
#   21: 0.07575117515982185,
#   17: 0.07264298754984397,
#   29: 0.05257290416008814,
#   12: 0.01,
#   18: 0.01,
#   19: 0.01,
#   23: 0.01,
#   25: 0.01},
#  1: {0: 5.92351382464146,
#   1: 5.618470637479485,
#   13: 5.573170662197833,
#   26: 4.581179338114108,
#   6: 3.3738759571430443,
#   18: 2.859242129898881,
#   10: 2.0958297452273604,
#   2: 1.698715729872559,
#   3: 1.6420221874518608,
#   22: 1.49707648407027,
#   24: 1.3727942452057185,
#   16: 1.2501489030492354,
#   28: 0.9959249888642988,
#   17: 0.9812930690021662,
#   29: 0.9306279006138702,
#   4: 0.7204370600382555,
#   15: 0.4057501126050641,
#   30: 0.2674754251497503,
#   7: 0.24128553023398472,
#   12: 0.23219003185399656,
#   11: 0.17829713051068677,
#   8: 0.10015483268572431,
#   5: 0.08591958909200412,
#   23: 0.07506146589391603,
#   9: 0.01,
#   14: 0.01,
#   19: 0.01,
#   20: 0.01,
#   21: 0.01,
#   25: 0.01,
#   27: 0.01,
#   31: 0.01},
#  2: {0: 6.166791325504177,
#   13: 6.023176398978473,
#   1: 5.921484501803335,
#   27: 4.974703151588264,
#   6: 3.4804781673829748,
#   19: 3.108459912650999,
#   10: 2.277117041723395,
#   2: 1.851881023374264,
#   3: 1.689634342920257,
#   23: 1.540384946139678,
#   17: 1.4462079955327645,
#   25: 1.4093930608546341,
#   29: 1.0816154322900202,
#   18: 1.0092961896151411,
#   30: 0.9574860395960424,
#   4: 0.8327523190489203,
#   15: 0.5281256692744783,
#   16: 0.41829154910387945,
#   7: 0.28745968843386577,
#   12: 0.2765483523718598,
#   31: 0.272068364741668,
#   11: 0.21189619881783425,
#   8: 0.10095048434567978,
#   5: 0.08793293078645285,
#   24: 0.07715469355926251,
#   9: 0.01,
#   14: 0.01,
#   20: 0.01,
#   21: 0.01,
#   22: 0.01,
#   26: 0.01,
#   28: 0.01,
#   32: 0.01},
#  3: {0: 8.088045371513502,
#   43: 3.969348091950579,
#   34: 3.93657435615664,
#   1: 3.444597591398456,
#   47: 3.434204831986938,
#   62: 3.4125647665200285,
#   61: 3.3094567432921487,
#   60: 3.120916357961169,
#   10: 2.657704456328429,
#   59: 2.4845925574691115,
#   63: 2.2096378288614327,
#   35: 1.9469325344054542,
#   27: 1.8554588564176426,
#   31: 1.824701208810682,
#   39: 1.5143775320047894,
#   12: 1.3684181971941118,
#   9: 1.2909655591604814,
#   2: 1.1935007883547926,
#   17: 1.0605396796775346,
#   51: 0.9998370229876448,
#   28: 0.9351021059846946,
#   4: 0.675235330509857,
#   58: 0.42879622365523334,
#   15: 0.424432670330407,
#   22: 0.4098828458127389,
#   52: 0.40835847945390785,
#   41: 0.35429226051543905,
#   13: 0.3364326428858412,
#   55: 0.2589230566304198,
#   33: 0.2503082513454038,
#   19: 0.23843430381194544,
#   21: 0.20264877285066035,
#   18: 0.18737037599303613,
#   20: 0.18074887355640368,
#   6: 0.16099082268387932,
#   5: 0.13893249262100804,
#   57: 0.11061987191716643,
#   16: 0.06305451532230376,
#   3: 0.01,
#   7: 0.01,
#   8: 0.01,
#   11: 0.01,
#   14: 0.01,
#   23: 0.01,
#   24: 0.01,
#   25: 0.01,
#   26: 0.01,
#   29: 0.01,
#   30: 0.01,
#   32: 0.01,
#   36: 0.01,
#   37: 0.01,
#   38: 0.01,
#   40: 0.01,
#   42: 0.01,
#   44: 0.01,
#   45: 0.01,
#   46: 0.01,
#   48: 0.01,
#   49: 0.01,
#   50: 0.01,
#   53: 0.01,
#   54: 0.01,
#   56: 0.01}}

# %%
kw_counts = yake_keyword_frequency(documents, ngram_size=3)
sentences, indices, ranking = rank_yake(documents, kw_counts)
ranking
# Out:
# {0: {6: 0.051666666666666666,
#   1: 0.05040404040404041,
#   0: 0.05,
#   11: 0.03702702702702703,
#   24: 0.03142857142857143,
#   3: 0.028181818181818183,
#   16: 0.027777777777777776,
#   14: 0.027543859649122808,
#   8: 0.027341040462427746,
#   20: 0.024705882352941175,
#   22: 0.023452914798206277,
#   10: 0.021235955056179777,
#   2: 0.021152416356877323,
#   15: 0.020526315789473684,
#   27: 0.020256410256410257,
#   4: 0.020050251256281407,
#   26: 0.01819672131147541,
#   21: 0.01735294117647059,
#   17: 0.017142857142857144,
#   7: 0.016514657980456027,
#   28: 0.015952380952380954,
#   5: 0.01581395348837209,
#   13: 0.014901960784313726,
#   29: 0.014854368932038835,
#   9: 0.014255319148936171,
#   12: 0.01,
#   18: 0.01,
#   19: 0.01,
#   23: 0.01,
#   25: 0.01},
#  1: {6: 0.051666666666666666,
#   1: 0.05040404040404041,
#   0: 0.05,
#   13: 0.042432432432432436,
#   26: 0.03857142857142857,
#   3: 0.028181818181818183,
#   18: 0.027777777777777776,
#   16: 0.027543859649122808,
#   10: 0.027341040462427746,
#   22: 0.024705882352941175,
#   24: 0.023452914798206277,
#   30: 0.021904761904761906,
#   2: 0.021152416356877323,
#   17: 0.020526315789473684,
#   29: 0.020256410256410257,
#   4: 0.020050251256281407,
#   28: 0.01819672131147541,
#   8: 0.017812500000000002,
#   23: 0.01735294117647059,
#   7: 0.01584795321637427,
#   5: 0.01581395348837209,
#   12: 0.015617977528089888,
#   15: 0.014901960784313726,
#   11: 0.014255319148936171,
#   9: 0.01,
#   14: 0.01,
#   19: 0.01,
#   20: 0.01,
#   21: 0.01,
#   25: 0.01,
#   27: 0.01,
#   31: 0.01},
#  2: {6: 0.051666666666666666,
#   1: 0.050816326530612244,
#   0: 0.05,
#   13: 0.042432432432432436,
#   27: 0.03857142857142857,
#   3: 0.028181818181818183,
#   19: 0.027777777777777776,
#   17: 0.027543859649122808,
#   10: 0.027341040462427746,
#   23: 0.024705882352941175,
#   25: 0.023452914798206277,
#   31: 0.021904761904761906,
#   2: 0.021152416356877323,
#   18: 0.020526315789473684,
#   30: 0.020256410256410257,
#   4: 0.020050251256281407,
#   29: 0.01819672131147541,
#   8: 0.017812500000000002,
#   24: 0.01735294117647059,
#   15: 0.016329113924050634,
#   7: 0.01584795321637427,
#   5: 0.01581395348837209,
#   12: 0.015617977528089888,
#   16: 0.014901960784313726,
#   11: 0.014255319148936171,
#   9: 0.01,
#   14: 0.01,
#   20: 0.01,
#   21: 0.01,
#   22: 0.01,
#   26: 0.01,
#   28: 0.01,
#   32: 0.01},
#  3: {0: 0.07081081081081081,
#   43: 0.046363636363636364,
#   34: 0.04361344537815126,
#   35: 0.04125,
#   62: 0.04125,
#   61: 0.040303030303030306,
#   60: 0.03857142857142857,
#   47: 0.03469135802469136,
#   59: 0.03272727272727273,
#   12: 0.03222222222222222,
#   1: 0.03097902097902098,
#   63: 0.030202020202020202,
#   10: 0.03,
#   17: 0.02694915254237288,
#   27: 0.02694915254237288,
#   52: 0.02694915254237288,
#   31: 0.026666666666666665,
#   28: 0.024925373134328358,
#   13: 0.02388888888888889,
#   19: 0.023513513513513516,
#   4: 0.022244897959183673,
#   9: 0.021764705882352943,
#   39: 0.021363636363636362,
#   41: 0.02098901098901099,
#   2: 0.020869565217391306,
#   51: 0.01909090909090909,
#   21: 0.01819672131147541,
#   33: 0.01806451612903226,
#   15: 0.01677966101694915,
#   58: 0.01675675675675676,
#   22: 0.016451612903225808,
#   18: 0.015952380952380954,
#   57: 0.015952380952380954,
#   6: 0.014819277108433736,
#   5: 0.01411522633744856,
#   55: 0.014016064257028112,
#   20: 0.012754820936639119,
#   16: 0.012257336343115124,
#   3: 0.01,
#   7: 0.01,
#   8: 0.01,
#   11: 0.01,
#   14: 0.01,
#   23: 0.01,
#   24: 0.01,
#   25: 0.01,
#   26: 0.01,
#   29: 0.01,
#   30: 0.01,
#   32: 0.01,
#   36: 0.01,
#   37: 0.01,
#   38: 0.01,
#   40: 0.01,
#   42: 0.01,
#   44: 0.01,
#   45: 0.01,
#   46: 0.01,
#   48: 0.01,
#   49: 0.01,
#   50: 0.01,
#   53: 0.01,
#   54: 0.01,
#   56: 0.01}}

# %%
ranking
# Out:
# {0: {6: 0.051666666666666666,
#   1: 0.05040404040404041,
#   0: 0.05,
#   11: 0.03702702702702703,
#   24: 0.03142857142857143,
#   3: 0.028181818181818183,
#   16: 0.027777777777777776,
#   14: 0.027543859649122808,
#   8: 0.027341040462427746,
#   20: 0.024705882352941175,
#   22: 0.023452914798206277,
#   10: 0.021235955056179777,
#   2: 0.021152416356877323,
#   15: 0.020526315789473684,
#   27: 0.020256410256410257,
#   4: 0.020050251256281407,
#   26: 0.01819672131147541,
#   21: 0.01735294117647059,
#   17: 0.017142857142857144,
#   7: 0.016514657980456027,
#   28: 0.015952380952380954,
#   5: 0.01581395348837209,
#   13: 0.014901960784313726,
#   29: 0.014854368932038835,
#   9: 0.014255319148936171,
#   12: 0.01,
#   18: 0.01,
#   19: 0.01,
#   23: 0.01,
#   25: 0.01},
#  1: {6: 0.051666666666666666,
#   1: 0.05040404040404041,
#   0: 0.05,
#   13: 0.042432432432432436,
#   26: 0.03857142857142857,
#   3: 0.028181818181818183,
#   18: 0.027777777777777776,
#   16: 0.027543859649122808,
#   10: 0.027341040462427746,
#   22: 0.024705882352941175,
#   24: 0.023452914798206277,
#   30: 0.021904761904761906,
#   2: 0.021152416356877323,
#   17: 0.020526315789473684,
#   29: 0.020256410256410257,
#   4: 0.020050251256281407,
#   28: 0.01819672131147541,
#   8: 0.017812500000000002,
#   23: 0.01735294117647059,
#   7: 0.01584795321637427,
#   5: 0.01581395348837209,
#   12: 0.015617977528089888,
#   15: 0.014901960784313726,
#   11: 0.014255319148936171,
#   9: 0.01,
#   14: 0.01,
#   19: 0.01,
#   20: 0.01,
#   21: 0.01,
#   25: 0.01,
#   27: 0.01,
#   31: 0.01},
#  2: {6: 0.051666666666666666,
#   1: 0.050816326530612244,
#   0: 0.05,
#   13: 0.042432432432432436,
#   27: 0.03857142857142857,
#   3: 0.028181818181818183,
#   19: 0.027777777777777776,
#   17: 0.027543859649122808,
#   10: 0.027341040462427746,
#   23: 0.024705882352941175,
#   25: 0.023452914798206277,
#   31: 0.021904761904761906,
#   2: 0.021152416356877323,
#   18: 0.020526315789473684,
#   30: 0.020256410256410257,
#   4: 0.020050251256281407,
#   29: 0.01819672131147541,
#   8: 0.017812500000000002,
#   24: 0.01735294117647059,
#   15: 0.016329113924050634,
#   7: 0.01584795321637427,
#   5: 0.01581395348837209,
#   12: 0.015617977528089888,
#   16: 0.014901960784313726,
#   11: 0.014255319148936171,
#   9: 0.01,
#   14: 0.01,
#   20: 0.01,
#   21: 0.01,
#   22: 0.01,
#   26: 0.01,
#   28: 0.01,
#   32: 0.01},
#  3: {0: 0.07081081081081081,
#   43: 0.046363636363636364,
#   34: 0.04361344537815126,
#   35: 0.04125,
#   62: 0.04125,
#   61: 0.040303030303030306,
#   60: 0.03857142857142857,
#   47: 0.03469135802469136,
#   59: 0.03272727272727273,
#   12: 0.03222222222222222,
#   1: 0.03097902097902098,
#   63: 0.030202020202020202,
#   10: 0.03,
#   17: 0.02694915254237288,
#   27: 0.02694915254237288,
#   52: 0.02694915254237288,
#   31: 0.026666666666666665,
#   28: 0.024925373134328358,
#   13: 0.02388888888888889,
#   19: 0.023513513513513516,
#   4: 0.022244897959183673,
#   9: 0.021764705882352943,
#   39: 0.021363636363636362,
#   41: 0.02098901098901099,
#   2: 0.020869565217391306,
#   51: 0.01909090909090909,
#   21: 0.01819672131147541,
#   33: 0.01806451612903226,
#   15: 0.01677966101694915,
#   58: 0.01675675675675676,
#   22: 0.016451612903225808,
#   18: 0.015952380952380954,
#   57: 0.015952380952380954,
#   6: 0.014819277108433736,
#   5: 0.01411522633744856,
#   55: 0.014016064257028112,
#   20: 0.012754820936639119,
#   16: 0.012257336343115124,
#   3: 0.01,
#   7: 0.01,
#   8: 0.01,
#   11: 0.01,
#   14: 0.01,
#   23: 0.01,
#   24: 0.01,
#   25: 0.01,
#   26: 0.01,
#   29: 0.01,
#   30: 0.01,
#   32: 0.01,
#   36: 0.01,
#   37: 0.01,
#   38: 0.01,
#   40: 0.01,
#   42: 0.01,
#   44: 0.01,
#   45: 0.01,
#   46: 0.01,
#   48: 0.01,
#   49: 0.01,
#   50: 0.01,
#   53: 0.01,
#   54: 0.01,
#   56: 0.01}}

# %%
ranking
# Out:
# {0: {6: 0.051666666666666666,
#   1: 0.05040404040404041,
#   0: 0.05,
#   11: 0.03702702702702703,
#   24: 0.03142857142857143,
#   3: 0.028181818181818183,
#   16: 0.027777777777777776,
#   14: 0.027543859649122808,
#   8: 0.027341040462427746,
#   20: 0.024705882352941175,
#   22: 0.023452914798206277,
#   10: 0.021235955056179777,
#   2: 0.021152416356877323,
#   15: 0.020526315789473684,
#   27: 0.020256410256410257,
#   4: 0.020050251256281407,
#   26: 0.01819672131147541,
#   21: 0.01735294117647059,
#   17: 0.017142857142857144,
#   7: 0.016514657980456027,
#   28: 0.015952380952380954,
#   5: 0.01581395348837209,
#   13: 0.014901960784313726,
#   29: 0.014854368932038835,
#   9: 0.014255319148936171,
#   12: 0.01,
#   18: 0.01,
#   19: 0.01,
#   23: 0.01,
#   25: 0.01},
#  1: {6: 0.051666666666666666,
#   1: 0.05040404040404041,
#   0: 0.05,
#   13: 0.042432432432432436,
#   26: 0.03857142857142857,
#   3: 0.028181818181818183,
#   18: 0.027777777777777776,
#   16: 0.027543859649122808,
#   10: 0.027341040462427746,
#   22: 0.024705882352941175,
#   24: 0.023452914798206277,
#   30: 0.021904761904761906,
#   2: 0.021152416356877323,
#   17: 0.020526315789473684,
#   29: 0.020256410256410257,
#   4: 0.020050251256281407,
#   28: 0.01819672131147541,
#   8: 0.017812500000000002,
#   23: 0.01735294117647059,
#   7: 0.01584795321637427,
#   5: 0.01581395348837209,
#   12: 0.015617977528089888,
#   15: 0.014901960784313726,
#   11: 0.014255319148936171,
#   9: 0.01,
#   14: 0.01,
#   19: 0.01,
#   20: 0.01,
#   21: 0.01,
#   25: 0.01,
#   27: 0.01,
#   31: 0.01},
#  2: {6: 0.051666666666666666,
#   1: 0.050816326530612244,
#   0: 0.05,
#   13: 0.042432432432432436,
#   27: 0.03857142857142857,
#   3: 0.028181818181818183,
#   19: 0.027777777777777776,
#   17: 0.027543859649122808,
#   10: 0.027341040462427746,
#   23: 0.024705882352941175,
#   25: 0.023452914798206277,
#   31: 0.021904761904761906,
#   2: 0.021152416356877323,
#   18: 0.020526315789473684,
#   30: 0.020256410256410257,
#   4: 0.020050251256281407,
#   29: 0.01819672131147541,
#   8: 0.017812500000000002,
#   24: 0.01735294117647059,
#   15: 0.016329113924050634,
#   7: 0.01584795321637427,
#   5: 0.01581395348837209,
#   12: 0.015617977528089888,
#   16: 0.014901960784313726,
#   11: 0.014255319148936171,
#   9: 0.01,
#   14: 0.01,
#   20: 0.01,
#   21: 0.01,
#   22: 0.01,
#   26: 0.01,
#   28: 0.01,
#   32: 0.01},
#  3: {0: 0.07081081081081081,
#   43: 0.046363636363636364,
#   34: 0.04361344537815126,
#   35: 0.04125,
#   62: 0.04125,
#   61: 0.040303030303030306,
#   60: 0.03857142857142857,
#   47: 0.03469135802469136,
#   59: 0.03272727272727273,
#   12: 0.03222222222222222,
#   1: 0.03097902097902098,
#   63: 0.030202020202020202,
#   10: 0.03,
#   17: 0.02694915254237288,
#   27: 0.02694915254237288,
#   52: 0.02694915254237288,
#   31: 0.026666666666666665,
#   28: 0.024925373134328358,
#   13: 0.02388888888888889,
#   19: 0.023513513513513516,
#   4: 0.022244897959183673,
#   9: 0.021764705882352943,
#   39: 0.021363636363636362,
#   41: 0.02098901098901099,
#   2: 0.020869565217391306,
#   51: 0.01909090909090909,
#   21: 0.01819672131147541,
#   33: 0.01806451612903226,
#   15: 0.01677966101694915,
#   58: 0.01675675675675676,
#   22: 0.016451612903225808,
#   18: 0.015952380952380954,
#   57: 0.015952380952380954,
#   6: 0.014819277108433736,
#   5: 0.01411522633744856,
#   55: 0.014016064257028112,
#   20: 0.012754820936639119,
#   16: 0.012257336343115124,
#   3: 0.01,
#   7: 0.01,
#   8: 0.01,
#   11: 0.01,
#   14: 0.01,
#   23: 0.01,
#   24: 0.01,
#   25: 0.01,
#   26: 0.01,
#   29: 0.01,
#   30: 0.01,
#   32: 0.01,
#   36: 0.01,
#   37: 0.01,
#   38: 0.01,
#   40: 0.01,
#   42: 0.01,
#   44: 0.01,
#   45: 0.01,
#   46: 0.01,
#   48: 0.01,
#   49: 0.01,
#   50: 0.01,
#   53: 0.01,
#   54: 0.01,
#   56: 0.01}}

# %%
# Import the necessary modules
from gensim.summarization.summarizer import summarize, sentences, rank_sentences

# Define the text that you want to summarize
text = "Insert the text that you want to summarize here"

# Use the sentences function to extract the individual sentences
sentences = sentences(text)

# Use the rank_sentences function to assign a score to each sentence
scores = rank_sentences(sentences, summary)

# Print the score for each sentence
for sentence, score in zip(sentences, scores):
    print(f"Sentence: {sentence}")
    print(f"Score: {score}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-19-db628672bfd8> in <module>
#       1 # Import the necessary modules
# ----> 2 from gensim.summarization.summarizer import summarize, sentences, rank_sentences
#       3
#       4 # Define the text that you want to summarize
#       5 text = "Insert the text that you want to summarize here"
#
# ModuleNotFoundError: No module named 'gensim.summarization'

# %%
# !pip install gensim
# Out:
# Requirement already satisfied: gensim in /home/lukas/ml/lib/python3.6/site-packages (4.2.0)
# Requirement already satisfied: scipy>=0.18.1 in /home/lukas/ml/lib/python3.6/site-packages (from gensim) (1.5.4)
# Requirement already satisfied: smart-open>=1.8.1 in /home/lukas/ml/lib/python3.6/site-packages (from gensim) (5.2.1)
# Requirement already satisfied: numpy>=1.17.0 in /home/lukas/ml/lib/python3.6/site-packages (from gensim) (1.19.5)

# %%
g = summarizer.get_graph(documents[0])

# %%
g.edges()
# Out:
# [('tradit suggest time donald trump set asid say speak style rise inaugur moment',
#   'buck tradit ignor altogeth got donald trump inaugur moment'),
#  ('buck tradit ignor altogeth got donald trump inaugur moment',
#   'tradit suggest time donald trump set asid say speak style rise inaugur moment'),
#  ('tradit suggest time donald trump set asid say speak style rise inaugur moment',
#   'trump stand west capitol friday deliv inaugur address side wait come bear unifi messag divid nation decid play persona disrupt establish order'),
#  ('trump stand west capitol friday deliv inaugur address side wait come bear unifi messag divid nation decid play persona disrupt establish order',
#   'tradit suggest time donald trump set asid say speak style rise inaugur moment'),
#  ('tradit suggest time donald trump set asid say speak style rise inaugur moment',
#   'trump tend balanc act style content tell launch presid'),
#  ('trump tend balanc act style content tell launch presid',
#   'tradit suggest time donald trump set asid say speak style rise inaugur moment'),
#  ('tradit suggest time donald trump set asid say speak style rise inaugur moment',
#   'inaugur address meant age said kathleen hall jamieson communic professor director annenberg public polici center univers pennsylvania particular import ve divis elect need presid peopl includ vehement oppos elect trump'),
#  ('inaugur address meant age said kathleen hall jamieson communic professor director annenberg public polici center univers pennsylvania particular import ve divis elect need presid peopl includ vehement oppos elect trump',
#   'tradit suggest time donald trump set asid say speak style rise inaugur moment'),
#  ('tradit suggest time donald trump set asid say speak style rise inaugur moment',
#   'trump told fox tuesday ll start address word thank everybodi includ presid barack obama wife michell gracious presid elect show deliv straight forward prepar address republican convent larg stuck script shut anti hillari clinton chant lock crowd gop loyalist'),
#  ('trump told fox tuesday ll start address word thank everybodi includ presid barack obama wife michell gracious presid elect show deliv straight forward prepar address republican convent larg stuck script shut anti hillari clinton chant lock crowd gop loyalist',
#   'tradit suggest time donald trump set asid say speak style rise inaugur moment'),
#  ('tradit suggest time donald trump set asid say speak style rise inaugur moment',
#   'inaugur address contrast need inher aspir speech said michael gerson wrote speech presid georg w'),
#  ('inaugur address contrast need inher aspir speech said michael gerson wrote speech presid georg w',
#   'tradit suggest time donald trump set asid say speak style rise inaugur moment'),
#  ('tradit suggest time donald trump set asid say speak style rise inaugur moment',
#   'bush frequent trump critic futur vision veteran speechwrit plenti advic trump chief wordsmith stephen miller short overdo gravita gloat victori tour deviat script'),
#  ('bush frequent trump critic futur vision veteran speechwrit plenti advic trump chief wordsmith stephen miller short overdo gravita gloat victori tour deviat script',
#   'tradit suggest time donald trump set asid say speak style rise inaugur moment'),
#  ('tradit suggest time donald trump set asid say speak style rise inaugur moment',
#   'oh undo success inaugur address intemper tweet hour later'),
#  ('oh undo success inaugur address intemper tweet hour later',
#   'tradit suggest time donald trump set asid say speak style rise inaugur moment'),
#  ('tradit suggest time donald trump set asid say speak style rise inaugur moment',
#   'trump victori speech elect night sound come unit peopl tweet featur call score settl petul'),
#  ('trump victori speech elect night sound come unit peopl tweet featur call score settl petul',
#   'tradit suggest time donald trump set asid say speak style rise inaugur moment'),
#  ('tradit suggest time donald trump set asid say speak style rise inaugur moment',
#   'wayn field washington univers expert presidenti rhetor said trump awkward situat go inaugur address man regard precis languag contempt respect candid revel take juvenil potshot campaign label rival stupid dumb bad know word declar ralli best word better word stupid right trump deliv statesmanlik speech hit right note field say know receiv come serious huge challeng refram trump tone presid want requir consist longer term shift field said'),
#  ('wayn field washington univers expert presidenti rhetor said trump awkward situat go inaugur address man regard precis languag contempt respect candid revel take juvenil potshot campaign label rival stupid dumb bad know word declar ralli best word better word stupid right trump deliv statesmanlik speech hit right note field say know receiv come serious huge challeng refram trump tone presid want requir consist longer term shift field said',
#   'tradit suggest time donald trump set asid say speak style rise inaugur moment'),
#  ('tradit suggest time donald trump set asid say speak style rise inaugur moment',
#   'trump speech benefit low expect cuff inflammatori style long big appeal soar rhetor obama exampl simpli wouldn ring true'),
#  ('trump speech benefit low expect cuff inflammatori style long big appeal soar rhetor obama exampl simpli wouldn ring true',
#   'tradit suggest time donald trump set asid say speak style rise inaugur moment'),
#  ('tradit suggest time donald trump set asid say speak style rise inaugur moment',
#   'time gerson caution trump face extra hurdl inaugur address won elect divid countri'),
#  ('time gerson caution trump face extra hurdl inaugur address won elect divid countri',
#   'tradit suggest time donald trump set asid say speak style rise inaugur moment'),
#  ('tradit suggest time donald trump set asid say speak style rise inaugur moment',
#   'trump know audienc includ plenti support elect challeng status quo address offer flavor trump disruptor disappoint eager sea chang way washington'),
#  ('trump know audienc includ plenti support elect challeng status quo address offer flavor trump disruptor disappoint eager sea chang way washington',
#   'tradit suggest time donald trump set asid say speak style rise inaugur moment'),
#  ('tradit suggest time donald trump set asid say speak style rise inaugur moment',
#   'friday larger question trump adjust speak style year past pledg act presidenti time right come'),
#  ('friday larger question trump adjust speak style year past pledg act presidenti time right come',
#   'tradit suggest time donald trump set asid say speak style rise inaugur moment'),
#  ('tradit suggest time donald trump set asid say speak style rise inaugur moment',
#   'presid go learn make use good speech said gerson note presid speak public event given day differ experienc campaign reward spontan extemporan huge portion presid case'),
#  ('presid go learn make use good speech said gerson note presid speak public event given day differ experienc campaign reward spontan extemporan huge portion presid case',
#   'tradit suggest time donald trump set asid say speak style rise inaugur moment'),
#  ('buck tradit ignor altogeth got donald trump inaugur moment',
#   'trump stand west capitol friday deliv inaugur address side wait come bear unifi messag divid nation decid play persona disrupt establish order'),
#  ('trump stand west capitol friday deliv inaugur address side wait come bear unifi messag divid nation decid play persona disrupt establish order',
#   'buck tradit ignor altogeth got donald trump inaugur moment'),
#  ('buck tradit ignor altogeth got donald trump inaugur moment',
#   'trump tend balanc act style content tell launch presid'),
#  ('trump tend balanc act style content tell launch presid',
#   'buck tradit ignor altogeth got donald trump inaugur moment'),
#  ('buck tradit ignor altogeth got donald trump inaugur moment',
#   'inaugur address meant age said kathleen hall jamieson communic professor director annenberg public polici center univers pennsylvania particular import ve divis elect need presid peopl includ vehement oppos elect trump'),
#  ('inaugur address meant age said kathleen hall jamieson communic professor director annenberg public polici center univers pennsylvania particular import ve divis elect need presid peopl includ vehement oppos elect trump',
#   'buck tradit ignor altogeth got donald trump inaugur moment'),
#  ('buck tradit ignor altogeth got donald trump inaugur moment',
#   'trump told fox tuesday ll start address word thank everybodi includ presid barack obama wife michell gracious presid elect show deliv straight forward prepar address republican convent larg stuck script shut anti hillari clinton chant lock crowd gop loyalist'),
#  ('trump told fox tuesday ll start address word thank everybodi includ presid barack obama wife michell gracious presid elect show deliv straight forward prepar address republican convent larg stuck script shut anti hillari clinton chant lock crowd gop loyalist',
#   'buck tradit ignor altogeth got donald trump inaugur moment'),
#  ('buck tradit ignor altogeth got donald trump inaugur moment',
#   'inaugur address contrast need inher aspir speech said michael gerson wrote speech presid georg w'),
#  ('inaugur address contrast need inher aspir speech said michael gerson wrote speech presid georg w',
#   'buck tradit ignor altogeth got donald trump inaugur moment'),
#  ('buck tradit ignor altogeth got donald trump inaugur moment',
#   'bush frequent trump critic futur vision veteran speechwrit plenti advic trump chief wordsmith stephen miller short overdo gravita gloat victori tour deviat script'),
#  ('bush frequent trump critic futur vision veteran speechwrit plenti advic trump chief wordsmith stephen miller short overdo gravita gloat victori tour deviat script',
#   'buck tradit ignor altogeth got donald trump inaugur moment'),
#  ('buck tradit ignor altogeth got donald trump inaugur moment',
#   'oh undo success inaugur address intemper tweet hour later'),
#  ('oh undo success inaugur address intemper tweet hour later',
#   'buck tradit ignor altogeth got donald trump inaugur moment'),
#  ('buck tradit ignor altogeth got donald trump inaugur moment',
#   'trump victori speech elect night sound come unit peopl tweet featur call score settl petul'),
#  ('trump victori speech elect night sound come unit peopl tweet featur call score settl petul',
#   'buck tradit ignor altogeth got donald trump inaugur moment'),
#  ('buck tradit ignor altogeth got donald trump inaugur moment',
#   'wayn field washington univers expert presidenti rhetor said trump awkward situat go inaugur address man regard precis languag contempt respect candid revel take juvenil potshot campaign label rival stupid dumb bad know word declar ralli best word better word stupid right trump deliv statesmanlik speech hit right note field say know receiv come serious huge challeng refram trump tone presid want requir consist longer term shift field said'),
#  ('wayn field washington univers expert presidenti rhetor said trump awkward situat go inaugur address man regard precis languag contempt respect candid revel take juvenil potshot campaign label rival stupid dumb bad know word declar ralli best word better word stupid right trump deliv statesmanlik speech hit right note field say know receiv come serious huge challeng refram trump tone presid want requir consist longer term shift field said',
#   'buck tradit ignor altogeth got donald trump inaugur moment'),
#  ('buck tradit ignor altogeth got donald trump inaugur moment',
#   'trump speech benefit low expect cuff inflammatori style long big appeal soar rhetor obama exampl simpli wouldn ring true'),
#  ('trump speech benefit low expect cuff inflammatori style long big appeal soar rhetor obama exampl simpli wouldn ring true',
#   'buck tradit ignor altogeth got donald trump inaugur moment'),
#  ('buck tradit ignor altogeth got donald trump inaugur moment',
#   'time gerson caution trump face extra hurdl inaugur address won elect divid countri'),
#  ('time gerson caution trump face extra hurdl inaugur address won elect divid countri',
#   'buck tradit ignor altogeth got donald trump inaugur moment'),
#  ('buck tradit ignor altogeth got donald trump inaugur moment',
#   'trump know audienc includ plenti support elect challeng status quo address offer flavor trump disruptor disappoint eager sea chang way washington'),
#  ('trump know audienc includ plenti support elect challeng status quo address offer flavor trump disruptor disappoint eager sea chang way washington',
#   'buck tradit ignor altogeth got donald trump inaugur moment'),
#  ('buck tradit ignor altogeth got donald trump inaugur moment',
#   'friday larger question trump adjust speak style year past pledg act presidenti time right come'),
#  ('friday larger question trump adjust speak style year past pledg act presidenti time right come',
#   'buck tradit ignor altogeth got donald trump inaugur moment'),
#  ('trump stand west capitol friday deliv inaugur address side wait come bear unifi messag divid nation decid play persona disrupt establish order',
#   'trump tend balanc act style content tell launch presid'),
#  ('trump tend balanc act style content tell launch presid',
#   'trump stand west capitol friday deliv inaugur address side wait come bear unifi messag divid nation decid play persona disrupt establish order'),
#  ('trump stand west capitol friday deliv inaugur address side wait come bear unifi messag divid nation decid play persona disrupt establish order',
#   'inaugur address meant age said kathleen hall jamieson communic professor director annenberg public polici center univers pennsylvania particular import ve divis elect need presid peopl includ vehement oppos elect trump'),
#  ('inaugur address meant age said kathleen hall jamieson communic professor director annenberg public polici center univers pennsylvania particular import ve divis elect need presid peopl includ vehement oppos elect trump',
#   'trump stand west capitol friday deliv inaugur address side wait come bear unifi messag divid nation decid play persona disrupt establish order'),
#  ('trump stand west capitol friday deliv inaugur address side wait come bear unifi messag divid nation decid play persona disrupt establish order',
#   'kennedi said deepli involv prepar address expect deliv person speech return big theme campaign includ deep love countri'),
#  ('kennedi said deepli involv prepar address expect deliv person speech return big theme campaign includ deep love countri',
#   'trump stand west capitol friday deliv inaugur address side wait come bear unifi messag divid nation decid play persona disrupt establish order'),
#  ('trump stand west capitol friday deliv inaugur address side wait come bear unifi messag divid nation decid play persona disrupt establish order',
#   'trump told fox tuesday ll start address word thank everybodi includ presid barack obama wife michell gracious presid elect show deliv straight forward prepar address republican convent larg stuck script shut anti hillari clinton chant lock crowd gop loyalist'),
#  ('trump told fox tuesday ll start address word thank everybodi includ presid barack obama wife michell gracious presid elect show deliv straight forward prepar address republican convent larg stuck script shut anti hillari clinton chant lock crowd gop loyalist',
#   'trump stand west capitol friday deliv inaugur address side wait come bear unifi messag divid nation decid play persona disrupt establish order'),
#  ('trump stand west capitol friday deliv inaugur address side wait come bear unifi messag divid nation decid play persona disrupt establish order',
#   'address strike dark tone sketch portrait america crisi later embrac chant support freewheel campaign ralli'),
#  ('address strike dark tone sketch portrait america crisi later embrac chant support freewheel campaign ralli',
#   'trump stand west capitol friday deliv inaugur address side wait come bear unifi messag divid nation decid play persona disrupt establish order'),
#  ('trump stand west capitol friday deliv inaugur address side wait come bear unifi messag divid nation decid play persona disrupt establish order',
#   'inaugur address contrast need inher aspir speech said michael gerson wrote speech presid georg w'),
#  ('inaugur address contrast need inher aspir speech said michael gerson wrote speech presid georg w',
#   'trump stand west capitol friday deliv inaugur address side wait come bear unifi messag divid nation decid play persona disrupt establish order'),
#  ('trump stand west capitol friday deliv inaugur address side wait come bear unifi messag divid nation decid play persona disrupt establish order',
#   'bush frequent trump critic futur vision veteran speechwrit plenti advic trump chief wordsmith stephen miller short overdo gravita gloat victori tour deviat script'),
#  ('bush frequent trump critic futur vision veteran speechwrit plenti advic trump chief wordsmith stephen miller short overdo gravita gloat victori tour deviat script',
#   'trump stand west capitol friday deliv inaugur address side wait come bear unifi messag divid nation decid play persona disrupt establish order'),
#  ('trump stand west capitol friday deliv inaugur address side wait come bear unifi messag divid nation decid play persona disrupt establish order',
#   'oh undo success inaugur address intemper tweet hour later'),
#  ('oh undo success inaugur address intemper tweet hour later',
#   'trump stand west capitol friday deliv inaugur address side wait come bear unifi messag divid nation decid play persona disrupt establish order'),
#  ('trump stand west capitol friday deliv inaugur address side wait come bear unifi messag divid nation decid play persona disrupt establish order',
#   'trump victori speech elect night sound come unit peopl tweet featur call score settl petul'),
#  ('trump victori speech elect night sound come unit peopl tweet featur call score settl petul',
#   'trump stand west capitol friday deliv inaugur address side wait come bear unifi messag divid nation decid play persona disrupt establish order'),
#  ('trump stand west capitol friday deliv inaugur address side wait come bear unifi messag divid nation decid play persona disrupt establish order',
#   'wayn field washington univers expert presidenti rhetor said trump awkward situat go inaugur address man regard precis languag contempt respect candid revel take juvenil potshot campaign label rival stupid dumb bad know word declar ralli best word better word stupid right trump deliv statesmanlik speech hit right note field say know receiv come serious huge challeng refram trump tone presid want requir consist longer term shift field said'),
#  ('wayn field washington univers expert presidenti rhetor said trump awkward situat go inaugur address man regard precis languag contempt respect candid revel take juvenil potshot campaign label rival stupid dumb bad know word declar ralli best word better word stupid right trump deliv statesmanlik speech hit right note field say know receiv come serious huge challeng refram trump tone presid want requir consist longer term shift field said',
#   'trump stand west capitol friday deliv inaugur address side wait come bear unifi messag divid nation decid play persona disrupt establish order'),
#  ('trump stand west capitol friday deliv inaugur address side wait come bear unifi messag divid nation decid play persona disrupt establish order',
#   'trump speech benefit low expect cuff inflammatori style long big appeal soar rhetor obama exampl simpli wouldn ring true'),
#  ('trump speech benefit low expect cuff inflammatori style long big appeal soar rhetor obama exampl simpli wouldn ring true',
#   'trump stand west capitol friday deliv inaugur address side wait come bear unifi messag divid nation decid play persona disrupt establish order'),
#  ('trump stand west capitol friday deliv inaugur address side wait come bear unifi messag divid nation decid play persona disrupt establish order',
#   'time gerson caution trump face extra hurdl inaugur address won elect divid countri'),
#  ('time gerson caution trump face extra hurdl inaugur address won elect divid countri',
#   'trump stand west capitol friday deliv inaugur address side wait come bear unifi messag divid nation decid play persona disrupt establish order'),
#  ('trump stand west capitol friday deliv inaugur address side wait come bear unifi messag divid nation decid play persona disrupt establish order',
#   'trump know audienc includ plenti support elect challeng status quo address offer flavor trump disruptor disappoint eager sea chang way washington'),
#  ('trump know audienc includ plenti support elect challeng status quo address offer flavor trump disruptor disappoint eager sea chang way washington',
#   'trump stand west capitol friday deliv inaugur address side wait come bear unifi messag divid nation decid play persona disrupt establish order'),
#  ('trump stand west capitol friday deliv inaugur address side wait come bear unifi messag divid nation decid play persona disrupt establish order',
#   'friday larger question trump adjust speak style year past pledg act presidenti time right come'),
#  ('friday larger question trump adjust speak style year past pledg act presidenti time right come',
#   'trump stand west capitol friday deliv inaugur address side wait come bear unifi messag divid nation decid play persona disrupt establish order'),
#  ('trump tend balanc act style content tell launch presid',
#   'inaugur address meant age said kathleen hall jamieson communic professor director annenberg public polici center univers pennsylvania particular import ve divis elect need presid peopl includ vehement oppos elect trump'),
#  ('inaugur address meant age said kathleen hall jamieson communic professor director annenberg public polici center univers pennsylvania particular import ve divis elect need presid peopl includ vehement oppos elect trump',
#   'trump tend balanc act style content tell launch presid'),
#  ('trump tend balanc act style content tell launch presid',
#   'spoken admir recent week speech past presid ronald reagan john f'),
#  ('spoken admir recent week speech past presid ronald reagan john f',
#   'trump tend balanc act style content tell launch presid'),
#  ('trump tend balanc act style content tell launch presid',
#   'trump told fox tuesday ll start address word thank everybodi includ presid barack obama wife michell gracious presid elect show deliv straight forward prepar address republican convent larg stuck script shut anti hillari clinton chant lock crowd gop loyalist'),
#  ('trump told fox tuesday ll start address word thank everybodi includ presid barack obama wife michell gracious presid elect show deliv straight forward prepar address republican convent larg stuck script shut anti hillari clinton chant lock crowd gop loyalist',
#   'trump tend balanc act style content tell launch presid'),
#  ('trump tend balanc act style content tell launch presid',
#   'inaugur address contrast need inher aspir speech said michael gerson wrote speech presid georg w'),
#  ('inaugur address contrast need inher aspir speech said michael gerson wrote speech presid georg w',
#   'trump tend balanc act style content tell launch presid'),
#  ('trump tend balanc act style content tell launch presid',
#   'bush frequent trump critic futur vision veteran speechwrit plenti advic trump chief wordsmith stephen miller short overdo gravita gloat victori tour deviat script'),
#  ('bush frequent trump critic futur vision veteran speechwrit plenti advic trump chief wordsmith stephen miller short overdo gravita gloat victori tour deviat script',
#   'trump tend balanc act style content tell launch presid'),
#  ('trump tend balanc act style content tell launch presid',
#   'trump victori speech elect night sound come unit peopl tweet featur call score settl petul'),
#  ('trump victori speech elect night sound come unit peopl tweet featur call score settl petul',
#   'trump tend balanc act style content tell launch presid'),
#  ('trump tend balanc act style content tell launch presid',
#   'wayn field washington univers expert presidenti rhetor said trump awkward situat go inaugur address man regard precis languag contempt respect candid revel take juvenil potshot campaign label rival stupid dumb bad know word declar ralli best word better word stupid right trump deliv statesmanlik speech hit right note field say know receiv come serious huge challeng refram trump tone presid want requir consist longer term shift field said'),
#  ('wayn field washington univers expert presidenti rhetor said trump awkward situat go inaugur address man regard precis languag contempt respect candid revel take juvenil potshot campaign label rival stupid dumb bad know word declar ralli best word better word stupid right trump deliv statesmanlik speech hit right note field say know receiv come serious huge challeng refram trump tone presid want requir consist longer term shift field said',
#   'trump tend balanc act style content tell launch presid'),
#  ('trump tend balanc act style content tell launch presid',
#   'trump speech benefit low expect cuff inflammatori style long big appeal soar rhetor obama exampl simpli wouldn ring true'),
#  ('trump speech benefit low expect cuff inflammatori style long big appeal soar rhetor obama exampl simpli wouldn ring true',
#   'trump tend balanc act style content tell launch presid'),
#  ('trump tend balanc act style content tell launch presid',
#   'time gerson caution trump face extra hurdl inaugur address won elect divid countri'),
#  ('time gerson caution trump face extra hurdl inaugur address won elect divid countri',
#   'trump tend balanc act style content tell launch presid'),
#  ('trump tend balanc act style content tell launch presid',
#   'method won creat initi challeng presid ralli peopl broad agenda vision said'),
#  ('method won creat initi challeng presid ralli peopl broad agenda vision said',
#   'trump tend balanc act style content tell launch presid'),
#  ('trump tend balanc act style content tell launch presid',
#   'trump know audienc includ plenti support elect challeng status quo address offer flavor trump disruptor disappoint eager sea chang way washington'),
#  ('trump know audienc includ plenti support elect challeng status quo address offer flavor trump disruptor disappoint eager sea chang way washington',
#   'trump tend balanc act style content tell launch presid'),
#  ('trump tend balanc act style content tell launch presid',
#   'friday larger question trump adjust speak style year past pledg act presidenti time right come'),
#  ('friday larger question trump adjust speak style year past pledg act presidenti time right come',
#   'trump tend balanc act style content tell launch presid'),
#  ('trump tend balanc act style content tell launch presid',
#   'presid go learn make use good speech said gerson note presid speak public event given day differ experienc campaign reward spontan extemporan huge portion presid case'),
#  ('presid go learn make use good speech said gerson note presid speak public event given day differ experienc campaign reward spontan extemporan huge portion presid case',
#   'trump tend balanc act style content tell launch presid'),
#  ('inaugur address meant age said kathleen hall jamieson communic professor director annenberg public polici center univers pennsylvania particular import ve divis elect need presid peopl includ vehement oppos elect trump',
#   'spoken admir recent week speech past presid ronald reagan john f'),
#  ('spoken admir recent week speech past presid ronald reagan john f',
#   'inaugur address meant age said kathleen hall jamieson communic professor director annenberg public polici center univers pennsylvania particular import ve divis elect need presid peopl includ vehement oppos elect trump'),
#  ('inaugur address meant age said kathleen hall jamieson communic professor director annenberg public polici center univers pennsylvania particular import ve divis elect need presid peopl includ vehement oppos elect trump',
#   'kennedi said deepli involv prepar address expect deliv person speech return big theme campaign includ deep love countri'),
#  ('kennedi said deepli involv prepar address expect deliv person speech return big theme campaign includ deep love countri',
#   'inaugur address meant age said kathleen hall jamieson communic professor director annenberg public polici center univers pennsylvania particular import ve divis elect need presid peopl includ vehement oppos elect trump'),
#  ('inaugur address meant age said kathleen hall jamieson communic professor director annenberg public polici center univers pennsylvania particular import ve divis elect need presid peopl includ vehement oppos elect trump',
#   'trump told fox tuesday ll start address word thank everybodi includ presid barack obama wife michell gracious presid elect show deliv straight forward prepar address republican convent larg stuck script shut anti hillari clinton chant lock crowd gop loyalist'),
#  ('trump told fox tuesday ll start address word thank everybodi includ presid barack obama wife michell gracious presid elect show deliv straight forward prepar address republican convent larg stuck script shut anti hillari clinton chant lock crowd gop loyalist',
#   'inaugur address meant age said kathleen hall jamieson communic professor director annenberg public polici center univers pennsylvania particular import ve divis elect need presid peopl includ vehement oppos elect trump'),
#  ('inaugur address meant age said kathleen hall jamieson communic professor director annenberg public polici center univers pennsylvania particular import ve divis elect need presid peopl includ vehement oppos elect trump',
#   'address strike dark tone sketch portrait america crisi later embrac chant support freewheel campaign ralli'),
#  ('address strike dark tone sketch portrait america crisi later embrac chant support freewheel campaign ralli',
#   'inaugur address meant age said kathleen hall jamieson communic professor director annenberg public polici center univers pennsylvania particular import ve divis elect need presid peopl includ vehement oppos elect trump'),
#  ('inaugur address meant age said kathleen hall jamieson communic professor director annenberg public polici center univers pennsylvania particular import ve divis elect need presid peopl includ vehement oppos elect trump',
#   'inaugur address contrast need inher aspir speech said michael gerson wrote speech presid georg w'),
#  ('inaugur address contrast need inher aspir speech said michael gerson wrote speech presid georg w',
#   'inaugur address meant age said kathleen hall jamieson communic professor director annenberg public polici center univers pennsylvania particular import ve divis elect need presid peopl includ vehement oppos elect trump'),
#  ('inaugur address meant age said kathleen hall jamieson communic professor director annenberg public polici center univers pennsylvania particular import ve divis elect need presid peopl includ vehement oppos elect trump',
#   'bush frequent trump critic futur vision veteran speechwrit plenti advic trump chief wordsmith stephen miller short overdo gravita gloat victori tour deviat script'),
#  ('bush frequent trump critic futur vision veteran speechwrit plenti advic trump chief wordsmith stephen miller short overdo gravita gloat victori tour deviat script',
#   'inaugur address meant age said kathleen hall jamieson communic professor director annenberg public polici center univers pennsylvania particular import ve divis elect need presid peopl includ vehement oppos elect trump'),
#  ('inaugur address meant age said kathleen hall jamieson communic professor director annenberg public polici center univers pennsylvania particular import ve divis elect need presid peopl includ vehement oppos elect trump',
#   'oh undo success inaugur address intemper tweet hour later'),
#  ('oh undo success inaugur address intemper tweet hour later',
#   'inaugur address meant age said kathleen hall jamieson communic professor director annenberg public polici center univers pennsylvania particular import ve divis elect need presid peopl includ vehement oppos elect trump'),
#  ('inaugur address meant age said kathleen hall jamieson communic professor director annenberg public polici center univers pennsylvania particular import ve divis elect need presid peopl includ vehement oppos elect trump',
#   'trump victori speech elect night sound come unit peopl tweet featur call score settl petul'),
#  ('trump victori speech elect night sound come unit peopl tweet featur call score settl petul',
#   'inaugur address meant age said kathleen hall jamieson communic professor director annenberg public polici center univers pennsylvania particular import ve divis elect need presid peopl includ vehement oppos elect trump'),
#  ('inaugur address meant age said kathleen hall jamieson communic professor director annenberg public polici center univers pennsylvania particular import ve divis elect need presid peopl includ vehement oppos elect trump',
#   'wayn field washington univers expert presidenti rhetor said trump awkward situat go inaugur address man regard precis languag contempt respect candid revel take juvenil potshot campaign label rival stupid dumb bad know word declar ralli best word better word stupid right trump deliv statesmanlik speech hit right note field say know receiv come serious huge challeng refram trump tone presid want requir consist longer term shift field said'),
#  ('wayn field washington univers expert presidenti rhetor said trump awkward situat go inaugur address man regard precis languag contempt respect candid revel take juvenil potshot campaign label rival stupid dumb bad know word declar ralli best word better word stupid right trump deliv statesmanlik speech hit right note field say know receiv come serious huge challeng refram trump tone presid want requir consist longer term shift field said',
#   'inaugur address meant age said kathleen hall jamieson communic professor director annenberg public polici center univers pennsylvania particular import ve divis elect need presid peopl includ vehement oppos elect trump'),
#  ('inaugur address meant age said kathleen hall jamieson communic professor director annenberg public polici center univers pennsylvania particular import ve divis elect need presid peopl includ vehement oppos elect trump',
#   'trump speech benefit low expect cuff inflammatori style long big appeal soar rhetor obama exampl simpli wouldn ring true'),
#  ('trump speech benefit low expect cuff inflammatori style long big appeal soar rhetor obama exampl simpli wouldn ring true',
#   'inaugur address meant age said kathleen hall jamieson communic professor director annenberg public polici center univers pennsylvania particular import ve divis elect need presid peopl includ vehement oppos elect trump'),
#  ('inaugur address meant age said kathleen hall jamieson communic professor director annenberg public polici center univers pennsylvania particular import ve divis elect need presid peopl includ vehement oppos elect trump',
#   'high level attent low expect far like exceed expect jamieson said'),
#  ('high level attent low expect far like exceed expect jamieson said',
#   'inaugur address meant age said kathleen hall jamieson communic professor director annenberg public polici center univers pennsylvania particular import ve divis elect need presid peopl includ vehement oppos elect trump'),
#  ('inaugur address meant age said kathleen hall jamieson communic professor director annenberg public polici center univers pennsylvania particular import ve divis elect need presid peopl includ vehement oppos elect trump',
#   'time gerson caution trump face extra hurdl inaugur address won elect divid countri'),
#  ('time gerson caution trump face extra hurdl inaugur address won elect divid countri',
#   'inaugur address meant age said kathleen hall jamieson communic professor director annenberg public polici center univers pennsylvania particular import ve divis elect need presid peopl includ vehement oppos elect trump'),
#  ('inaugur address meant age said kathleen hall jamieson communic professor director annenberg public polici center univers pennsylvania particular import ve divis elect need presid peopl includ vehement oppos elect trump',
#   'method won creat initi challeng presid ralli peopl broad agenda vision said'),
#  ('method won creat initi challeng presid ralli peopl broad agenda vision said',
#   'inaugur address meant age said kathleen hall jamieson communic professor director annenberg public polici center univers pennsylvania particular import ve divis elect need presid peopl includ vehement oppos elect trump'),
#  ('inaugur address meant age said kathleen hall jamieson communic professor director annenberg public polici center univers pennsylvania particular import ve divis elect need presid peopl includ vehement oppos elect trump',
#   'trump know audienc includ plenti support elect challeng status quo address offer flavor trump disruptor disappoint eager sea chang way washington'),
#  ('trump know audienc includ plenti support elect challeng status quo address offer flavor trump disruptor disappoint eager sea chang way washington',
#   'inaugur address meant age said kathleen hall jamieson communic professor director annenberg public polici center univers pennsylvania particular import ve divis elect need presid peopl includ vehement oppos elect trump'),
#  ('inaugur address meant age said kathleen hall jamieson communic professor director annenberg public polici center univers pennsylvania particular import ve divis elect need presid peopl includ vehement oppos elect trump',
#   'friday larger question trump adjust speak style year past pledg act presidenti time right come'),
#  ('friday larger question trump adjust speak style year past pledg act presidenti time right come',
#   'inaugur address meant age said kathleen hall jamieson communic professor director annenberg public polici center univers pennsylvania particular import ve divis elect need presid peopl includ vehement oppos elect trump'),
#  ('inaugur address meant age said kathleen hall jamieson communic professor director annenberg public polici center univers pennsylvania particular import ve divis elect need presid peopl includ vehement oppos elect trump',
#   'presid go learn make use good speech said gerson note presid speak public event given day differ experienc campaign reward spontan extemporan huge portion presid case'),
#  ('presid go learn make use good speech said gerson note presid speak public event given day differ experienc campaign reward spontan extemporan huge portion presid case',
#   'inaugur address meant age said kathleen hall jamieson communic professor director annenberg public polici center univers pennsylvania particular import ve divis elect need presid peopl includ vehement oppos elect trump'),
#  ('spoken admir recent week speech past presid ronald reagan john f',
#   'kennedi said deepli involv prepar address expect deliv person speech return big theme campaign includ deep love countri'),
#  ('kennedi said deepli involv prepar address expect deliv person speech return big theme campaign includ deep love countri',
#   'spoken admir recent week speech past presid ronald reagan john f'),
#  ('spoken admir recent week speech past presid ronald reagan john f',
#   'trump told fox tuesday ll start address word thank everybodi includ presid barack obama wife michell gracious presid elect show deliv straight forward prepar address republican convent larg stuck script shut anti hillari clinton chant lock crowd gop loyalist'),
#  ('trump told fox tuesday ll start address word thank everybodi includ presid barack obama wife michell gracious presid elect show deliv straight forward prepar address republican convent larg stuck script shut anti hillari clinton chant lock crowd gop loyalist',
#   'spoken admir recent week speech past presid ronald reagan john f'),
#  ('spoken admir recent week speech past presid ronald reagan john f',
#   'inaugur address contrast need inher aspir speech said michael gerson wrote speech presid georg w'),
#  ('inaugur address contrast need inher aspir speech said michael gerson wrote speech presid georg w',
#   'spoken admir recent week speech past presid ronald reagan john f'),
#  ('spoken admir recent week speech past presid ronald reagan john f',
#   'trump victori speech elect night sound come unit peopl tweet featur call score settl petul'),
#  ('trump victori speech elect night sound come unit peopl tweet featur call score settl petul',
#   'spoken admir recent week speech past presid ronald reagan john f'),
#  ('spoken admir recent week speech past presid ronald reagan john f',
#   'wayn field washington univers expert presidenti rhetor said trump awkward situat go inaugur address man regard precis languag contempt respect candid revel take juvenil potshot campaign label rival stupid dumb bad know word declar ralli best word better word stupid right trump deliv statesmanlik speech hit right note field say know receiv come serious huge challeng refram trump tone presid want requir consist longer term shift field said'),
#  ('wayn field washington univers expert presidenti rhetor said trump awkward situat go inaugur address man regard precis languag contempt respect candid revel take juvenil potshot campaign label rival stupid dumb bad know word declar ralli best word better word stupid right trump deliv statesmanlik speech hit right note field say know receiv come serious huge challeng refram trump tone presid want requir consist longer term shift field said',
#   'spoken admir recent week speech past presid ronald reagan john f'),
#  ('spoken admir recent week speech past presid ronald reagan john f',
#   'trump speech benefit low expect cuff inflammatori style long big appeal soar rhetor obama exampl simpli wouldn ring true'),
#  ('trump speech benefit low expect cuff inflammatori style long big appeal soar rhetor obama exampl simpli wouldn ring true',
#   'spoken admir recent week speech past presid ronald reagan john f'),
#  ('spoken admir recent week speech past presid ronald reagan john f',
#   'method won creat initi challeng presid ralli peopl broad agenda vision said'),
#  ('method won creat initi challeng presid ralli peopl broad agenda vision said',
#   'spoken admir recent week speech past presid ronald reagan john f'),
#  ('spoken admir recent week speech past presid ronald reagan john f',
#   'friday larger question trump adjust speak style year past pledg act presidenti time right come'),
#  ('friday larger question trump adjust speak style year past pledg act presidenti time right come',
#   'spoken admir recent week speech past presid ronald reagan john f'),
#  ('spoken admir recent week speech past presid ronald reagan john f',
#   'presid go learn make use good speech said gerson note presid speak public event given day differ experienc campaign reward spontan extemporan huge portion presid case'),
#  ('presid go learn make use good speech said gerson note presid speak public event given day differ experienc campaign reward spontan extemporan huge portion presid case',
#   'spoken admir recent week speech past presid ronald reagan john f'),
#  ('kennedi said deepli involv prepar address expect deliv person speech return big theme campaign includ deep love countri',
#   'trump told fox tuesday ll start address word thank everybodi includ presid barack obama wife michell gracious presid elect show deliv straight forward prepar address republican convent larg stuck script shut anti hillari clinton chant lock crowd gop loyalist'),
#  ('trump told fox tuesday ll start address word thank everybodi includ presid barack obama wife michell gracious presid elect show deliv straight forward prepar address republican convent larg stuck script shut anti hillari clinton chant lock crowd gop loyalist',
#   'kennedi said deepli involv prepar address expect deliv person speech return big theme campaign includ deep love countri'),
#  ('kennedi said deepli involv prepar address expect deliv person speech return big theme campaign includ deep love countri',
#   'address strike dark tone sketch portrait america crisi later embrac chant support freewheel campaign ralli'),
#  ('address strike dark tone sketch portrait america crisi later embrac chant support freewheel campaign ralli',
#   'kennedi said deepli involv prepar address expect deliv person speech return big theme campaign includ deep love countri'),
#  ('kennedi said deepli involv prepar address expect deliv person speech return big theme campaign includ deep love countri',
#   'inaugur address contrast need inher aspir speech said michael gerson wrote speech presid georg w'),
#  ('inaugur address contrast need inher aspir speech said michael gerson wrote speech presid georg w',
#   'kennedi said deepli involv prepar address expect deliv person speech return big theme campaign includ deep love countri'),
#  ('kennedi said deepli involv prepar address expect deliv person speech return big theme campaign includ deep love countri',
#   'oh undo success inaugur address intemper tweet hour later'),
#  ('oh undo success inaugur address intemper tweet hour later',
#   'kennedi said deepli involv prepar address expect deliv person speech return big theme campaign includ deep love countri'),
#  ('kennedi said deepli involv prepar address expect deliv person speech return big theme campaign includ deep love countri',
#   'trump victori speech elect night sound come unit peopl tweet featur call score settl petul'),
#  ('trump victori speech elect night sound come unit peopl tweet featur call score settl petul',
#   'kennedi said deepli involv prepar address expect deliv person speech return big theme campaign includ deep love countri'),
#  ('kennedi said deepli involv prepar address expect deliv person speech return big theme campaign includ deep love countri',
#   'wayn field washington univers expert presidenti rhetor said trump awkward situat go inaugur address man regard precis languag contempt respect candid revel take juvenil potshot campaign label rival stupid dumb bad know word declar ralli best word better word stupid right trump deliv statesmanlik speech hit right note field say know receiv come serious huge challeng refram trump tone presid want requir consist longer term shift field said'),
#  ('wayn field washington univers expert presidenti rhetor said trump awkward situat go inaugur address man regard precis languag contempt respect candid revel take juvenil potshot campaign label rival stupid dumb bad know word declar ralli best word better word stupid right trump deliv statesmanlik speech hit right note field say know receiv come serious huge challeng refram trump tone presid want requir consist longer term shift field said',
#   'kennedi said deepli involv prepar address expect deliv person speech return big theme campaign includ deep love countri'),
#  ('kennedi said deepli involv prepar address expect deliv person speech return big theme campaign includ deep love countri',
#   'trump speech benefit low expect cuff inflammatori style long big appeal soar rhetor obama exampl simpli wouldn ring true'),
#  ('trump speech benefit low expect cuff inflammatori style long big appeal soar rhetor obama exampl simpli wouldn ring true',
#   'kennedi said deepli involv prepar address expect deliv person speech return big theme campaign includ deep love countri'),
#  ('kennedi said deepli involv prepar address expect deliv person speech return big theme campaign includ deep love countri',
#   'high level attent low expect far like exceed expect jamieson said'),
#  ('high level attent low expect far like exceed expect jamieson said',
#   'kennedi said deepli involv prepar address expect deliv person speech return big theme campaign includ deep love countri'),
#  ('kennedi said deepli involv prepar address expect deliv person speech return big theme campaign includ deep love countri',
#   'time gerson caution trump face extra hurdl inaugur address won elect divid countri'),
#  ('time gerson caution trump face extra hurdl inaugur address won elect divid countri',
#   'kennedi said deepli involv prepar address expect deliv person speech return big theme campaign includ deep love countri'),
# ...
#   'trump victori speech elect night sound come unit peopl tweet featur call score settl petul'),
#  ('trump victori speech elect night sound come unit peopl tweet featur call score settl petul',
#   'friday larger question trump adjust speak style year past pledg act presidenti time right come'),
#  ('friday larger question trump adjust speak style year past pledg act presidenti time right come',
#   'trump victori speech elect night sound come unit peopl tweet featur call score settl petul'),
#  ('trump victori speech elect night sound come unit peopl tweet featur call score settl petul',
#   'presid go learn make use good speech said gerson note presid speak public event given day differ experienc campaign reward spontan extemporan huge portion presid case'),
#  ('presid go learn make use good speech said gerson note presid speak public event given day differ experienc campaign reward spontan extemporan huge portion presid case',
#   'trump victori speech elect night sound come unit peopl tweet featur call score settl petul'),
#  ('wayn field washington univers expert presidenti rhetor said trump awkward situat go inaugur address man regard precis languag contempt respect candid revel take juvenil potshot campaign label rival stupid dumb bad know word declar ralli best word better word stupid right trump deliv statesmanlik speech hit right note field say know receiv come serious huge challeng refram trump tone presid want requir consist longer term shift field said',
#   'trump speech benefit low expect cuff inflammatori style long big appeal soar rhetor obama exampl simpli wouldn ring true'),
#  ('trump speech benefit low expect cuff inflammatori style long big appeal soar rhetor obama exampl simpli wouldn ring true',
#   'wayn field washington univers expert presidenti rhetor said trump awkward situat go inaugur address man regard precis languag contempt respect candid revel take juvenil potshot campaign label rival stupid dumb bad know word declar ralli best word better word stupid right trump deliv statesmanlik speech hit right note field say know receiv come serious huge challeng refram trump tone presid want requir consist longer term shift field said'),
#  ('wayn field washington univers expert presidenti rhetor said trump awkward situat go inaugur address man regard precis languag contempt respect candid revel take juvenil potshot campaign label rival stupid dumb bad know word declar ralli best word better word stupid right trump deliv statesmanlik speech hit right note field say know receiv come serious huge challeng refram trump tone presid want requir consist longer term shift field said',
#   'high level attent low expect far like exceed expect jamieson said'),
#  ('high level attent low expect far like exceed expect jamieson said',
#   'wayn field washington univers expert presidenti rhetor said trump awkward situat go inaugur address man regard precis languag contempt respect candid revel take juvenil potshot campaign label rival stupid dumb bad know word declar ralli best word better word stupid right trump deliv statesmanlik speech hit right note field say know receiv come serious huge challeng refram trump tone presid want requir consist longer term shift field said'),
#  ('wayn field washington univers expert presidenti rhetor said trump awkward situat go inaugur address man regard precis languag contempt respect candid revel take juvenil potshot campaign label rival stupid dumb bad know word declar ralli best word better word stupid right trump deliv statesmanlik speech hit right note field say know receiv come serious huge challeng refram trump tone presid want requir consist longer term shift field said',
#   'time gerson caution trump face extra hurdl inaugur address won elect divid countri'),
#  ('time gerson caution trump face extra hurdl inaugur address won elect divid countri',
#   'wayn field washington univers expert presidenti rhetor said trump awkward situat go inaugur address man regard precis languag contempt respect candid revel take juvenil potshot campaign label rival stupid dumb bad know word declar ralli best word better word stupid right trump deliv statesmanlik speech hit right note field say know receiv come serious huge challeng refram trump tone presid want requir consist longer term shift field said'),
#  ('wayn field washington univers expert presidenti rhetor said trump awkward situat go inaugur address man regard precis languag contempt respect candid revel take juvenil potshot campaign label rival stupid dumb bad know word declar ralli best word better word stupid right trump deliv statesmanlik speech hit right note field say know receiv come serious huge challeng refram trump tone presid want requir consist longer term shift field said',
#   'method won creat initi challeng presid ralli peopl broad agenda vision said'),
#  ('method won creat initi challeng presid ralli peopl broad agenda vision said',
#   'wayn field washington univers expert presidenti rhetor said trump awkward situat go inaugur address man regard precis languag contempt respect candid revel take juvenil potshot campaign label rival stupid dumb bad know word declar ralli best word better word stupid right trump deliv statesmanlik speech hit right note field say know receiv come serious huge challeng refram trump tone presid want requir consist longer term shift field said'),
#  ('wayn field washington univers expert presidenti rhetor said trump awkward situat go inaugur address man regard precis languag contempt respect candid revel take juvenil potshot campaign label rival stupid dumb bad know word declar ralli best word better word stupid right trump deliv statesmanlik speech hit right note field say know receiv come serious huge challeng refram trump tone presid want requir consist longer term shift field said',
#   'trump know audienc includ plenti support elect challeng status quo address offer flavor trump disruptor disappoint eager sea chang way washington'),
#  ('trump know audienc includ plenti support elect challeng status quo address offer flavor trump disruptor disappoint eager sea chang way washington',
#   'wayn field washington univers expert presidenti rhetor said trump awkward situat go inaugur address man regard precis languag contempt respect candid revel take juvenil potshot campaign label rival stupid dumb bad know word declar ralli best word better word stupid right trump deliv statesmanlik speech hit right note field say know receiv come serious huge challeng refram trump tone presid want requir consist longer term shift field said'),
#  ('wayn field washington univers expert presidenti rhetor said trump awkward situat go inaugur address man regard precis languag contempt respect candid revel take juvenil potshot campaign label rival stupid dumb bad know word declar ralli best word better word stupid right trump deliv statesmanlik speech hit right note field say know receiv come serious huge challeng refram trump tone presid want requir consist longer term shift field said',
#   'friday larger question trump adjust speak style year past pledg act presidenti time right come'),
#  ('friday larger question trump adjust speak style year past pledg act presidenti time right come',
#   'wayn field washington univers expert presidenti rhetor said trump awkward situat go inaugur address man regard precis languag contempt respect candid revel take juvenil potshot campaign label rival stupid dumb bad know word declar ralli best word better word stupid right trump deliv statesmanlik speech hit right note field say know receiv come serious huge challeng refram trump tone presid want requir consist longer term shift field said'),
#  ('wayn field washington univers expert presidenti rhetor said trump awkward situat go inaugur address man regard precis languag contempt respect candid revel take juvenil potshot campaign label rival stupid dumb bad know word declar ralli best word better word stupid right trump deliv statesmanlik speech hit right note field say know receiv come serious huge challeng refram trump tone presid want requir consist longer term shift field said',
#   'presid go learn make use good speech said gerson note presid speak public event given day differ experienc campaign reward spontan extemporan huge portion presid case'),
#  ('presid go learn make use good speech said gerson note presid speak public event given day differ experienc campaign reward spontan extemporan huge portion presid case',
#   'wayn field washington univers expert presidenti rhetor said trump awkward situat go inaugur address man regard precis languag contempt respect candid revel take juvenil potshot campaign label rival stupid dumb bad know word declar ralli best word better word stupid right trump deliv statesmanlik speech hit right note field say know receiv come serious huge challeng refram trump tone presid want requir consist longer term shift field said'),
#  ('trump speech benefit low expect cuff inflammatori style long big appeal soar rhetor obama exampl simpli wouldn ring true',
#   'high level attent low expect far like exceed expect jamieson said'),
#  ('high level attent low expect far like exceed expect jamieson said',
#   'trump speech benefit low expect cuff inflammatori style long big appeal soar rhetor obama exampl simpli wouldn ring true'),
#  ('trump speech benefit low expect cuff inflammatori style long big appeal soar rhetor obama exampl simpli wouldn ring true',
#   'time gerson caution trump face extra hurdl inaugur address won elect divid countri'),
#  ('time gerson caution trump face extra hurdl inaugur address won elect divid countri',
#   'trump speech benefit low expect cuff inflammatori style long big appeal soar rhetor obama exampl simpli wouldn ring true'),
#  ('trump speech benefit low expect cuff inflammatori style long big appeal soar rhetor obama exampl simpli wouldn ring true',
#   'trump know audienc includ plenti support elect challeng status quo address offer flavor trump disruptor disappoint eager sea chang way washington'),
#  ('trump know audienc includ plenti support elect challeng status quo address offer flavor trump disruptor disappoint eager sea chang way washington',
#   'trump speech benefit low expect cuff inflammatori style long big appeal soar rhetor obama exampl simpli wouldn ring true'),
#  ('trump speech benefit low expect cuff inflammatori style long big appeal soar rhetor obama exampl simpli wouldn ring true',
#   'friday larger question trump adjust speak style year past pledg act presidenti time right come'),
#  ('friday larger question trump adjust speak style year past pledg act presidenti time right come',
#   'trump speech benefit low expect cuff inflammatori style long big appeal soar rhetor obama exampl simpli wouldn ring true'),
#  ('trump speech benefit low expect cuff inflammatori style long big appeal soar rhetor obama exampl simpli wouldn ring true',
#   'presid go learn make use good speech said gerson note presid speak public event given day differ experienc campaign reward spontan extemporan huge portion presid case'),
#  ('presid go learn make use good speech said gerson note presid speak public event given day differ experienc campaign reward spontan extemporan huge portion presid case',
#   'trump speech benefit low expect cuff inflammatori style long big appeal soar rhetor obama exampl simpli wouldn ring true'),
#  ('high level attent low expect far like exceed expect jamieson said',
#   'method won creat initi challeng presid ralli peopl broad agenda vision said'),
#  ('method won creat initi challeng presid ralli peopl broad agenda vision said',
#   'high level attent low expect far like exceed expect jamieson said'),
#  ('high level attent low expect far like exceed expect jamieson said',
#   'presid go learn make use good speech said gerson note presid speak public event given day differ experienc campaign reward spontan extemporan huge portion presid case'),
#  ('presid go learn make use good speech said gerson note presid speak public event given day differ experienc campaign reward spontan extemporan huge portion presid case',
#   'high level attent low expect far like exceed expect jamieson said'),
#  ('time gerson caution trump face extra hurdl inaugur address won elect divid countri',
#   'method won creat initi challeng presid ralli peopl broad agenda vision said'),
#  ('method won creat initi challeng presid ralli peopl broad agenda vision said',
#   'time gerson caution trump face extra hurdl inaugur address won elect divid countri'),
#  ('time gerson caution trump face extra hurdl inaugur address won elect divid countri',
#   'trump know audienc includ plenti support elect challeng status quo address offer flavor trump disruptor disappoint eager sea chang way washington'),
#  ('trump know audienc includ plenti support elect challeng status quo address offer flavor trump disruptor disappoint eager sea chang way washington',
#   'time gerson caution trump face extra hurdl inaugur address won elect divid countri'),
#  ('time gerson caution trump face extra hurdl inaugur address won elect divid countri',
#   'friday larger question trump adjust speak style year past pledg act presidenti time right come'),
#  ('friday larger question trump adjust speak style year past pledg act presidenti time right come',
#   'time gerson caution trump face extra hurdl inaugur address won elect divid countri'),
#  ('time gerson caution trump face extra hurdl inaugur address won elect divid countri',
#   'presid go learn make use good speech said gerson note presid speak public event given day differ experienc campaign reward spontan extemporan huge portion presid case'),
#  ('presid go learn make use good speech said gerson note presid speak public event given day differ experienc campaign reward spontan extemporan huge portion presid case',
#   'time gerson caution trump face extra hurdl inaugur address won elect divid countri'),
#  ('method won creat initi challeng presid ralli peopl broad agenda vision said',
#   'trump know audienc includ plenti support elect challeng status quo address offer flavor trump disruptor disappoint eager sea chang way washington'),
#  ('trump know audienc includ plenti support elect challeng status quo address offer flavor trump disruptor disappoint eager sea chang way washington',
#   'method won creat initi challeng presid ralli peopl broad agenda vision said'),
#  ('method won creat initi challeng presid ralli peopl broad agenda vision said',
#   'presid go learn make use good speech said gerson note presid speak public event given day differ experienc campaign reward spontan extemporan huge portion presid case'),
#  ('presid go learn make use good speech said gerson note presid speak public event given day differ experienc campaign reward spontan extemporan huge portion presid case',
#   'method won creat initi challeng presid ralli peopl broad agenda vision said'),
#  ('trump know audienc includ plenti support elect challeng status quo address offer flavor trump disruptor disappoint eager sea chang way washington',
#   'friday larger question trump adjust speak style year past pledg act presidenti time right come'),
#  ('friday larger question trump adjust speak style year past pledg act presidenti time right come',
#   'trump know audienc includ plenti support elect challeng status quo address offer flavor trump disruptor disappoint eager sea chang way washington'),
#  ('friday larger question trump adjust speak style year past pledg act presidenti time right come',
#   'presid go learn make use good speech said gerson note presid speak public event given day differ experienc campaign reward spontan extemporan huge portion presid case'),
#  ('presid go learn make use good speech said gerson note presid speak public event given day differ experienc campaign reward spontan extemporan huge portion presid case',
#   'friday larger question trump adjust speak style year past pledg act presidenti time right come')]

# %%
import spacy
nlp = spacy.load("en_core_web_sm")

# %%
# !pip uninstall pytextrank
# Out:
# Found existing installation: pytextrank 2.1.0
# Uninstalling pytextrank-2.1.0:
#   Would remove:
#     /home/lukas/ml/lib/python3.6/site-packages/pytextrank-2.1.0.dist-info/*
#     /home/lukas/ml/lib/python3.6/site-packages/pytextrank/*
# Proceed (Y/n)? ^C
# ERROR: Operation cancelled by user

# %%
import pytextrank
nlp.add_pipe("textrank", last=True)
doc = nlp(documents[0])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-c534878ab084> in <module>
#       1 import pytextrank
# ----> 2 nlp.add_pipe("textrank", last=True)
#       3 doc = nlp(documents[0])
#
# ~/ml/lib/python3.6/site-packages/spacy/language.py in add_pipe(self, factory_name, name, before, after, first, last, source, config, raw_config, validate)
#     798                 config=config,
#     799                 raw_config=raw_config,
# --> 800                 validate=validate,
#     801             )
#     802         pipe_index = self._get_pipe_index(before, after, first, last)
#
# ~/ml/lib/python3.6/site-packages/spacy/language.py in create_pipe(self, factory_name, name, config, raw_config, validate)
#     653                 lang_code=self.lang,
#     654             )
# --> 655             raise ValueError(err)
#     656         pipe_meta = self.get_factory_meta(factory_name)
#     657         # This is unideal, but the alternative would mean you always need to
#
# ValueError: [E002] Can't find factory for 'textrank' for language English (en). This usually happens when spaCy calls `nlp.create_pipe` with a custom component name that's not registered on the current language class. If you're using a Transformer, make sure to install 'spacy-transformers'. If you're using a custom component, make sure you've added the decorator `@Language.component` (for function components) or `@Language.factory` (for class components).
#
# Available factories: attribute_ruler, tok2vec, merge_noun_chunks, merge_entities, merge_subtokens, token_splitter, doc_cleaner, parser, beam_parser, lemmatizer, trainable_lemmatizer, entity_linker, ner, beam_ner, entity_ruler, tagger, morphologizer, senter, sentencizer, textcat, spancat, future_entity_ruler, span_ruler, textcat_multilabel, en.lemmatizer

# %%
# !pip install sumy
# Out:
# Collecting sumy
#   Downloading sumy-0.11.0-py2.py3-none-any.whl (97 kB)
#      |████████████████████████████████| 97 kB 1.2 MB/s
# Requirement already satisfied: nltk>=3.0.2 in /home/lukas/ml/lib/python3.6/site-packages (from sumy) (3.6.7)
# Requirement already satisfied: docopt<0.7,>=0.6.1 in /home/lukas/ml/lib/python3.6/site-packages (from sumy) (0.6.2)
# Requirement already satisfied: requests>=2.7.0 in /home/lukas/ml/lib/python3.6/site-packages (from sumy) (2.27.1)
# Collecting pycountry>=18.2.23
#   Downloading pycountry-22.3.5.tar.gz (10.1 MB)
#      |████████████████████████████████| 10.1 MB 644 kB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting breadability>=0.1.20
#   Downloading breadability-0.1.20.tar.gz (32 kB)
#   Preparing metadata (setup.py) ... done
# Collecting chardet
#   Downloading chardet-5.0.0-py3-none-any.whl (193 kB)
#      |████████████████████████████████| 193 kB 8.7 MB/s
# Collecting lxml>=2.0
#   Downloading lxml-4.9.1-cp36-cp36m-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (6.4 MB)
#      |████████████████████████████████| 6.4 MB 4.8 MB/s
# Requirement already satisfied: regex>=2021.8.3 in /home/lukas/ml/lib/python3.6/site-packages (from nltk>=3.0.2->sumy) (2022.7.25)
# Requirement already satisfied: joblib in /home/lukas/ml/lib/python3.6/site-packages (from nltk>=3.0.2->sumy) (1.1.0)
# Requirement already satisfied: click in /home/lukas/ml/lib/python3.6/site-packages (from nltk>=3.0.2->sumy) (8.0.4)
# Requirement already satisfied: tqdm in /home/lukas/ml/lib/python3.6/site-packages (from nltk>=3.0.2->sumy) (4.64.0)
# Requirement already satisfied: setuptools in /home/lukas/ml/lib/python3.6/site-packages (from pycountry>=18.2.23->sumy) (59.6.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/lukas/ml/lib/python3.6/site-packages (from requests>=2.7.0->sumy) (1.26.11)
# Requirement already satisfied: idna<4,>=2.5 in /home/lukas/ml/lib/python3.6/site-packages (from requests>=2.7.0->sumy) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/lukas/ml/lib/python3.6/site-packages (from requests>=2.7.0->sumy) (2022.6.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/lukas/ml/lib/python3.6/site-packages (from requests>=2.7.0->sumy) (2.0.12)
# Requirement already satisfied: importlib-metadata in /home/lukas/ml/lib/python3.6/site-packages (from click->nltk>=3.0.2->sumy) (4.8.3)
# Requirement already satisfied: importlib-resources in /home/lukas/ml/lib/python3.6/site-packages (from tqdm->nltk>=3.0.2->sumy) (5.4.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /home/lukas/ml/lib/python3.6/site-packages (from importlib-metadata->click->nltk>=3.0.2->sumy) (4.1.1)
# Requirement already satisfied: zipp>=0.5 in /home/lukas/ml/lib/python3.6/site-packages (from importlib-metadata->click->nltk>=3.0.2->sumy) (3.6.0)
# Building wheels for collected packages: breadability, pycountry
#   Building wheel for breadability (setup.py) ... done
#   Created wheel for breadability: filename=breadability-0.1.20-py2.py3-none-any.whl size=21714 sha256=5e56cb1fae2c8968c0ac9dacb102f8160c65f71d74c2489b11d894ec20e2ade4
#   Stored in directory: /home/lukas/.cache/pip/wheels/bd/52/cd/cdbe91a70fa33c0e98d434717f0199b4f6c39f94103f75d443
#   Building wheel for pycountry (pyproject.toml) ... done
#   Created wheel for pycountry: filename=pycountry-22.3.5-py2.py3-none-any.whl size=10681845 sha256=0891c37070c9fb6a515e9013fc0b8e81c8ac71bc170ccd02191b06d76f0cc330
#   Stored in directory: /home/lukas/.cache/pip/wheels/81/2e/84/0aff7999dc68fdfeee5c31db245dc3e43cec9d957d1063375e
# Successfully built breadability pycountry
# Installing collected packages: lxml, chardet, pycountry, breadability, sumy
# Successfully installed breadability-0.1.20 chardet-5.0.0 lxml-4.9.1 pycountry-22.3.5 sumy-0.11.0

# %%
from sumy.parsers.plaintext import PlaintextParser
from sumy.nlp.tokenizers import Tokenizer
from sumy.summarizers.text_rank import TextRankSummarizer

def text_rank_importance(documents):  
    # Summarize using sumy TextRank
    summarizer = TextRankSummarizer()
    
    versions = len(documents)
    
    ranking = {version:{} for version in range(versions)}
    
    for version in range(versions):
        importance = {}
        
          # Creating text parser using tokenization
        parser = PlaintextParser.from_string(documents[version], Tokenizer("english"))
        ranked = summarizer.rate_sentences(parser.document)
        
        for i, score in enumerate(ranked.values()):
            importance[i] = score
        
        # sort indices by importance
        sorted_importance = {k: v for k, v in sorted(importance.items(), key=lambda item: item[1], 
                                                 reverse=True)}
        
        
        ranking[version] = sorted_importance
        
    return ranking

# %%
text_rank_importance(documents)[2]
# Out:
# {2: 0.05557051236740845,
#  4: 0.04545005150808341,
#  15: 0.04456532930859665,
#  11: 0.04249849243123687,
#  29: 0.041269843359644,
#  25: 0.0391743341358215,
#  28: 0.03841579130460456,
#  30: 0.0373086443841249,
#  32: 0.034960333747662636,
#  23: 0.0343488998515863,
#  7: 0.034094211310151855,
#  31: 0.03386563518247975,
#  27: 0.033211295675658,
#  26: 0.031937807100405995,
#  0: 0.03156691443014241,
#  16: 0.03130058070524169,
#  13: 0.030556022122641437,
#  10: 0.029231831624076263,
#  24: 0.02903318780274637,
#  19: 0.02850592981580828,
#  5: 0.027637006361198417,
#  12: 0.02762347378096177,
#  18: 0.027579514818786028,
#  3: 0.02592389463510852,
#  20: 0.02358671362145832,
#  9: 0.021646686532713396,
#  14: 0.021405218588119865,
#  8: 0.020036516077635295,
#  17: 0.01979878668006709,
#  1: 0.019065102825902045,
#  6: 0.014407807046615853,
#  22: 0.0138315354710631,
#  21: 0.010592079376824987}
